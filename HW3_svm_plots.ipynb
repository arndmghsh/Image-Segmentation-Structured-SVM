# %%
l_svm_trainloss = [0.652, 0.628, 0.626]
l_svm_testloss = [0.643, 0.641, 0.640]
EPOCHS = 3

# %%
import matplotlib.pyplot as plt
# Training and Testing CER Plots
fig, ax = plt.subplots(figsize = (8,5));


# plt.ylim(0,3.2)
# plt.xlim(0.5,10)
plt.plot(range(EPOCHS), l_svm_trainloss, label = 'Training')
plt.plot(range(EPOCHS), l_svm_testloss, label = 'Testing')
ax.legend()
ax.set_title('FCN + l-SVM', fontsize=16)
ax.set_xlabel('Epoch', fontsize=16);
ax.set_ylabel('Hinge Loss', fontsize=16);

# %%
struct_svm_trainloss = [16.31,  6.57, 5.06]
struct_svm_testloss = [7.55, 5.99, 4.65]

# %%
import matplotlib.pyplot as plt
# Training and Testing CER Plots
fig, ax = plt.subplots(figsize = (8,5));


# plt.ylim(0,3.2)
# plt.xlim(0.5,10)
plt.plot(range(EPOCHS), struct_svm_trainloss, label = 'Training')
plt.plot(range(EPOCHS), struct_svm_testloss, label = 'Testing')
ax.legend()
ax.set_title('FCN + s-SVN', fontsize=16)
ax.set_xlabel('Epoch', fontsize=16);
ax.set_ylabel('Structured Hinge Loss', fontsize=16);
